# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
year=[2000,2001,2002,2006,2014,2020]
pop=[1,4,6,2,7,3]
sns.scatterplot(x=year,y=pop)
plt.show()

# %%
pop=[1,4,1,2,4,5,6,3,2,1,2,5,6,7,8,8,56,4,2,2,1,2,4,56,7,9,90,6,4,3,2,1,2,4,65,7,98,6,2,7,3]
sns.countplot(y=pop)
plt.show()
