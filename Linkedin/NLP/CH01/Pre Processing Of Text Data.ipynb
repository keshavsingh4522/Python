# %% [markdown]
# # NLP Basics: Implementing a pipeline to clean text

# %% [markdown]
# ### Pre-processing text data
#
# Cleaning up the text data is necessary to highlight attributes that you're going to want your machine learning system to pick up on. Cleaning (or pre-processing) the data typically consists of a number of steps:
# 1. **Remove punctuation**
# 2. **Tokenization**
# 3. **Remove stopwords**
# 4. Lemmatize/Stem
#
# The first three steps are covered in this chapter as they're implemented in pretty much any text cleaning pipeline. Lemmatizing and stemming are covered in the next chapter as they're helpful but not critical.

# %%
import pandas as pd
pd.set_option('display.max_colwidth',100)
data=pd.read_csv('SMSSpamCollection.tsv',sep='\t',header=None)
data.columns=['label','body_text']
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
# what does the cleaned version look like
data_cleaned=pd.read_csv('SMSSpamCollection_cleaned.tsv',sep='\t')
data_cleaned.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                       body_text_nostop
# 0  ['ive', 'searching', 'right', 'words', 'thank', 'breather', 'promise', 'wont', 'take', 'help', '...
# ...

# %% [markdown]
# ### Remove punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
'I Like NLP.'=='I Like NLP'
# Out:
# False

# %%
def remove_punct(text):
    text_nopunct=[char for char in text if char not in string.punctuation]
    return text_nopunct

# %%
remove_punct('I Like NLP.')
# Out:
# ['I', ' ', 'L', 'i', 'k', 'e', ' ', 'N', 'L', 'P']

# %%
''.join(remove_punct('I Like NLP.'))
# Out:
# 'I Like NLP'

# %%
def remove_punct(text):
    text_nopunct=''.join([char for char in text if char not in string.punctuation])
    return text_nopunct
data['body_text_clean']=data['body_text'].apply(lambda x: remove_punct(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %% [markdown]
# ###  tokenization

# %%
import re
def tokenize(text):
    return re.split('\W+',text)
data['body_text_clean_tokenized']=data['body_text_clean'].apply(lambda x:tokenize(x.lower()))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %%
data['body_text_clean'].head()
# Out:
# 0    Ive been searching for the right words to thank you for this breather I promise i wont take your...
# 1    Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005 Text FA to 87121 to receive e...
# 2                                            Nah I dont think he goes to usf he lives around here though
# 3                            Even my brother is not like to speak with me They treat me like aids patent
# 4                                                                      I HAVE A DATE ON SUNDAY WITH WILL
# Name: body_text_clean, dtype: object

# %%
'NLP'=='nlp'
# Out:
# False

# %%
'AVhhftWREGDG'.lower()
# Out:
# 'avhhftwregdg'

# %% [markdown]
# ###  remove stopwords

# %%
import nltk
stopwords=nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(x):
    return [char for char in x if char not in stopwords]
data['body_text_clean_tokenized_stopwardsRemoved']=data['body_text_clean_tokenized'].apply(lambda x:remove_stopwords(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %%
remove_stopwords('I love You Keshav')
# Out:
# 'I lve Yu Kehv'

# %%
re.split('\s',"This is an interesting te+st")
# Out:
# ['This', 'is', 'an', 'interesting', 'te+st']
