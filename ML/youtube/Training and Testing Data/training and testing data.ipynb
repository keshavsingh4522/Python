# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
df[:-2]
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700

# %% [markdown]
# # Car Mileage v/s Sell price

# %%
plt.scatter(df[['Mileage']],df[['Sell Price($)']])
plt.show()

# %% [markdown]
# # Car Age v/s Sell price

# %%
plt.scatter(df[['Age(yrs)']],df[['Sell Price($)']])
plt.show()

# %% [markdown]
# ### based on above result apply linear regression

# %%
X=df[['Mileage','Age(yrs)']]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y=df[['Sell Price($)']]
y
# Out:
#     Sell Price($)
# 0           18000
# 1           34000
# 2           26100
# 3           40000
# 4           31500
# 5           26750
# 6           32000
# 7           19300
# 8           12000
# 9           22000
# 10          18700
# 11          19500
# 12          26000
# 13          27500
# 14          19400
# 15          35000
# 16          35500
# 17          19700
# 18          12800
# 19          28200

# %%
model=linear_model.LinearRegression()

# %%
# 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 14    82450         7
# 10    83000         7
# 0     69000         6
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 18    87600         8
# 2     57000         5
# 3     22500         2
# 15    25400         3
# 13    58780         4
# 9     67000         6
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 5     59000         5

# %%
y_train
# Out:
#     Sell Price($)
# 14          19400
# 10          18700
# 0           18000
# 6           32000
# 7           19300
# 8           12000
# 18          12800
# 2           26100
# 3           40000
# 15          35000
# 13          27500
# 9           22000
# 19          28200
# 12          26000
# 11          19500
# 5           26750

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 17    69000         5
# 16    28000         2
# 4     46000         4
# 1     35000         3

# %%
y_test
# Out:
#     Sell Price($)
# 17          19700
# 16          35500
# 4           31500
# 1           34000

# %%
clf=linear_model.LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf.predict(x_test)
# Out:
# array([[23635.59446745],
#        [38304.33091724],
#        [30704.00294807],
#        [34971.05900352]])

# %%
y_test
# Out:
#     Sell Price($)
# 17          19700
# 16          35500
# 4           31500
# 1           34000

# %%
clf.score(x_test,y_test)
#it compare with>>> clf.predict(x_test) and y_test
# Out:
# 0.8386084930448543
