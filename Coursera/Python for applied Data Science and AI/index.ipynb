# %% [markdown]
# n=

# %%
eval('3+4/5*6')
# Out:
# 7.800000000000001

# %%
"hello Mike".find("Mike")
# Out:
# 6

# %%
"ABC".replace("AB", "ab")
# Out:
# 'abC'

# %%
t=(2,3,4,56,6)
a=t
a
# Out:
# (2, 3, 4, 56, 6)

# %% [markdown]
# ***IMP***

# %%
a=(1,2,[4])
a[2]
# Out:
# [4]

# %%
a[2][0]
# Out:
# 4

# %% [markdown]
# # DICT

# %%
a={'a':1,'c':2}
a
# Out:
# {'a': 1, 'c': 2}

# %%
a.keys()
# Out:
# dict_keys(['a', 'c'])

# %%
z=a.values()
z
# Out:
# dict_values([1, 2])

# %%
for i in z:
    print(i)
# Out:
# 1
# 2

# %%
d={'a':1,'a':2}
d
# Out:
# {'a': 2}

# %% [markdown]
# # SET

# %%
s={'a',1,6,2}
s
# Out:
# {1, 2, 6, 'a'}

# %%
s.add('keshav')
s
# Out:
# {1, 2, 6, 'a', 'keshav'}

# %%
s.remove(6)
s
# Out:
# {1, 2, 'a', 'keshav'}

# %%
2 in s
# Out:
# True

# %%
a=6
if (a==6)==1:
    print('Yes')
if (a==6)==True:
    print('Yes')
# Out:
# Yes
# Yes

# %% [markdown]
# ***LOOPS***

# %%
for i,x in enumerate(['P','Q','R']):
    print(i,x)
# Out:
# 0 P
# 1 Q
# 2 R

# %%
2*'1'
# Out:
# '11'

# %% [markdown]
# # FILE

# %%
with open('k.txt','w') as file:
    file.write('keshav singh\nPradeep Singh\nGulkando Devi')
#     file.close()

# %%
file.name
# Out:
# 'k.txt'

# %%
with open('k.txt','r') as file:
    print(file.read())
# Out:
# keshav singh
# Pradeep Singh
# Gulkando Devi

# %%
with open('k.txt','r') as file:
    print(file.readlines())
# Out:
# ['keshav singh\n', 'Pradeep Singh\n', 'Gulkando Devi']

# %%
with open('k.txt','r') as file:
    print(file.readline())
    print(file.readline())
    print(file.readline())
# Out:
# keshav singh
#
# Pradeep Singh
#
# Gulkando Devi

# %%
with open('k.txt','r') as file:
    print(file.readline(4))
    print(file.readline())
    print(file.readline())
# Out:
# kesh
# av singh
#
# Pradeep Singh

# %% [markdown]
# # Pandas

# %%
with open('k.csv','w') as file:
    file.write('name,year\nKeshav Singh,1999\nPradeep Singh,2001\nPriya Jain,1999')

# %%
import pandas as pd
df=pd.read_csv('k.csv')
df
# Out:
#             name  year
# 0   Keshav Singh  1999
# 1  Pradeep Singh  2001
# 2     Priya Jain  1999

# %%
df['year'].unique()
# Out:
# array([1999, 2001])

# %%
df[['name','year']][df['year']>1999]
# Out:
#             name  year
# 1  Pradeep Singh  2001

# %% [markdown]
# # numpy

# %% [markdown]
# - 1-D

# %%
import numpy as np

# %%
a=np.array([0,2,4,7,2])
a
# Out:
# array([0, 2, 4, 7, 2])

# %%
a+10
# Out:
# array([10, 12, 14, 17, 12])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.size
# Out:
# 5

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (5,)

# %%
a.dtype
# Out:
# dtype('int64')

# %% [markdown]
# - Vector addition and subbtraction

# %%
a=np.array([1,1,1,1])
c=np.array([0,1,0,1])
a*c
# Out:
# array([0, 1, 0, 1])

# %%
np.dot(a,c)
# Out:
# 2

# %%
a+c
# Out:
# array([1, 2, 1, 2])

# %%
a-c
# Out:
# array([1, 0, 1, 0])

# %%
np.linspace(-2,2,num=5)
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
np.linspace(-2,2,num=10)
# Out:
# array([-2.        , -1.55555556, -1.11111111, -0.66666667, -0.22222222,
#         0.22222222,  0.66666667,  1.11111111,  1.55555556,  2.        ])

# %%
import matplotlib.pyplot as plt
x=np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x))
plt.show()

# %% [markdown]
# - 2-D

# %%
a2=np.array([[12,34,7],[23,1,6],[34,67,21]])
a2
# Out:
# array([[12, 34,  7],
#        [23,  1,  6],
#        [34, 67, 21]])

# %%
a2.ndim
# Out:
# 2

# %%
a2.size
# Out:
# 9

# %%
a2.shape
# Out:
# (3, 3)

# %%
a2.dtype
# Out:
# dtype('int64')

# %%
a3=np.array([[1,4,7],[2,1,1],[4,7,1]])
a3
# Out:
# array([[1, 4, 7],
#        [2, 1, 1],
#        [4, 7, 1]])

# %%
np.dot(a2,a3)
# Out:
# array([[108, 131, 125],
#        [ 49, 135, 168],
#        [252, 350, 326]])

# %%
a2*a3
# Out:
# array([[ 12, 136,  49],
#        [ 46,   1,   6],
#        [136, 469,  21]])
