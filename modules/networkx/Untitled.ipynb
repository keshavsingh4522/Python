# %% [markdown]
# PYTHON | Backtracking
#
# Complete ONLY the backtracking method where PASS needs to be edited, do not create other methods, do not copy/paste other answers or even re-name copy/pasted answers (will thumbs down/flag).
#
# Also indenting is not easy to do here.. provided screenshots for how methods should look like.
#
# Problem 1: Complete the function **bactrack** to generate all valid configurations of cameras that cover a network.

# %%
import networkx as nx
my_network = nx.gnp_random_graph(10, 0.25, seed=2021)
nx.draw(my_network, with_labels=True)

# %%
import networkx as nx
my_network = nx.gnp_random_graph(10, 0.25, seed=2021)
nx.draw(my_network, with_labels=True)

def is_valid(configuration, network):
    with_camera = []
    for i in range(len(configuration)):
        if configuration[i] == True:
            List = my_network[i]
        for x in List:
            if x not in with_camera:
                with_camera.append(x)

    if len(with_camera) == len(network):
        return True
    return False

def generate_configurations(network):
    def backtrack(i):
        if i==len(configuration):
            pass
        else:
            pass

    n = len(network.nodes)
    configuration = [None] * n
    backtrack(0)

# %% [markdown]
# ![](https://media.cheggcdn.com/media/3ac/3acca371-3f23-480e-bb79-e14e638f8c53/phpfbEd4Y)
# ![](https://media.cheggcdn.com/media/781/781206e9-c552-4522-9fc3-a452d52b9968/phpwXcfyK)
# ![](https://media.cheggcdn.com/media/781/781206e9-c552-4522-9fc3-a452d52b9968/phpwXcfyK)
